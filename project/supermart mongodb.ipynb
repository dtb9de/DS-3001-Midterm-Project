# %% [markdown]
# #### Import the Necessary Libraries

# %%
import os
import json
import numpy
import datetime
import pandas as pd

import pymongo
from sqlalchemy import create_engine

# %% [markdown]
# #### Declare & Assign Connection Variables for the MongoDB Server, the MySQL Server & Databases with which You'll be Working

# %%
mysql_uid = "root"
mysql_pwd = "Passw0rd123"

atlas_cluster_name = "sandbox.zibbf"
atlas_user_name = "m001-student"
atlas_password = "m001-mongodb-basics"

conn_str = {"local" : f"mongodb://localhost:27017/",
    "atlas" : f"mongodb+srv://{atlas_user_name}:{atlas_password}@{atlas_cluster_name}.mongodb.net"
}

src_dbname = "supermart"
dst_dbname = "supermart"

print(f"Local Connection String: {conn_str['local']}")
print(f"Atlas Connection String: {conn_str['local']}")
# Out:
# Local Connection String: mongodb://localhost:27017/
# Atlas Connection String: mongodb://localhost:27017/

# %% [markdown]
# #### Define Functions for Getting Data From and Setting Data Into Databases

# %%
def get_sql_dataframe(user_id, pwd, db_name, sql_query):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@localhost/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    
    '''Invoke the pd.read_sql() function to query the database, and fill a Pandas DataFrame.'''
    conn = sqlEngine.connect()
    dframe = pd.read_sql(sql_query, conn);
    conn.close()
    
    return dframe


def get_mongo_dataframe(connect_str, db_name, collection, query):
    '''Create a connection to MongoDB'''
    client = pymongo.MongoClient(connect_str)
    
    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = client[db_name]
    dframe = pd.DataFrame(list(db[collection].find(query)))
    dframe.drop(['_id'], axis=1, inplace=True)
    client.close()
    return dframe


def set_dataframe(user_id, pwd, db_name, df, table_name, pk_column, db_operation):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@localhost/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    '''Invoke the Pandas DataFrame .to_sql( ) function to either create, or append to, a table'''
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        sqlEngine.execute(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});")
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()

# %% [markdown]
# #### Populate MongoDB with Source Data
# You only need to run this cell once; however, the operation is *idempotent*.  In other words, it can be run multiple times without changing the end result.

# %%
client = pymongo.MongoClient(conn_str["local"])
db = client[src_dbname]

# Gets the path of the Current Working Directory for this Notebook, and then Appends the 'data' directory.
data_dir = os.path.join(os.getcwd(), 'data')

json_files = {"customer" : 'customer.json',
             "products" : "products.json"}

for file in json_files:
    db.drop_collection(file)
    json_file = os.path.join(data_dir, json_files[file])
    with open(json_file, 'r') as openfile:
        json_object = json.load(openfile)
        file = db[file]
        result = file.insert_many(json_object)
        #print(f"{file} was successfully loaded.")

        
client.close()

# %% [markdown]
# ### 1.0. Create and Populate the New Dimension Tables
# #### 1.1. Extract Data from the Source MongoDB Collections Into DataFrames

# %%
query = {}
collection = "customer"

df_customer = get_mongo_dataframe(conn_str['local'], src_dbname, collection, query)
df_customer.head(2)
# Out:
#   ﻿Order ID Customer Name      Category   Sub Category         City  \
# 0       OD1        Harish  Oil & Masala        Masalas      Vellore
# 1       OD2         Sudha     Beverages  Health Drinks  Krishnagiri
#
#    Order Date Region Sales Discount  Profit       State
# 0  11-08-2017  North  1254     0.12  401.28  Tamil Nadu
# 1  11-08-2017  South   749     0.18   149.8  Tamil Nadu

# %% [markdown]
# #### 1.2. Perform Any Necessary Transformations to the DataFrames

# %%
df_customer.rename(columns={"Order ID":"order_key",
                             "Customer Name":"customer_name",
                             "Category":"category",
                             "Sub Category":"sub_category",
                             "City":"city",
                             "Order Date":"order_date",
                             "Region":"region",
                             "Sales":"sales",
                             "Discount":"discount",
                             "Profit":"profit",
                             "State":"state",
                            }, inplace=True)
df_customer = df_customer.drop(df_customer.columns[0], 1)
df_customer.insert(0, "order_key", range(1, df_customer.shape[0]+1))
df_customer.head(2)
# Out:
# C:\Users\ds2002-02-student\AppData\Local\Temp\2\ipykernel_1820\2172527900.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_customer = df_customer.drop(df_customer.columns[0], 1)
#    order_key customer_name      category   sub_category         city  \
# 0          1        Harish  Oil & Masala        Masalas      Vellore
# 1          2         Sudha     Beverages  Health Drinks  Krishnagiri
#
#    order_date region sales discount  profit       state
# 0  11-08-2017  North  1254     0.12  401.28  Tamil Nadu
# 1  11-08-2017  South   749     0.18   149.8  Tamil Nadu

# %%
#print(df_customer["order_date"][0])
#print(len(df_customer))
for i in range(len(df_customer)):
    m, d, y = df_customer["order_date"][i].replace('/', '-').split('-')
    df_customer["order_date"][i] = y + '-' + m + '-' + d
    #print(i)
# This takes a while but works eventually
df_customer.head(2)
# Out:
# C:\Users\ds2002-02-student\AppData\Local\Temp\2\ipykernel_1820\1207755437.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_customer["order_date"][i] = y + '-' + m + '-' + d
#    order_key customer_name      category   sub_category         city  \
# 0          1        Harish  Oil & Masala        Masalas      Vellore
# 1          2         Sudha     Beverages  Health Drinks  Krishnagiri
#
#    order_date region sales discount  profit       state
# 0  2017-11-08  North  1254     0.12  401.28  Tamil Nadu
# 1  2017-11-08  South   749     0.18   149.8  Tamil Nadu

# %% [markdown]
# #### 1.3. Load the Transformed DataFrames into the New Data Warehouse by Creating New Tables
#
# Here we will call our **set_dataframe( )** function to create each dimension table. This function expects a number of parameters including the usual connection information (e.g., user_id, password, MySQL server name and database), the *table_name* we need to assign to the table, the *pandas DataFrame* we crafted to define & populate the table, the *name* we need to assign to the *primary_key* column, and finally, the database operation (insert or update).

# %%
dataframe = df_customer
table_name = 'customer'
primary_key = 'order_key'
db_operation = "insert"
set_dataframe(mysql_uid, mysql_pwd, dst_dbname, dataframe, table_name, primary_key, db_operation)
#This code chunk takes a while, I'm not sure why and I couldn't fix it. It works eventually tho

# %% [markdown]
# #### 1.4. Validate that the New Dimension Tables were Created.

# %%
sql_customer = "SELECT * FROM supermart.customer;"
df_customer = get_sql_dataframe(mysql_uid, mysql_pwd, dst_dbname, sql_customer)
df_customer.head(2)
# Out:
#    order_key customer_name      category   sub_category         city  \
# 0          1        Harish  Oil & Masala        Masalas      Vellore
# 1          2         Sudha     Beverages  Health Drinks  Krishnagiri
#
#    order_date region sales discount  profit       state
# 0  2017-11-08  North  1254     0.12  401.28  Tamil Nadu
# 1  2017-11-08  South   749     0.18   149.8  Tamil Nadu

# %% [markdown]
# ### 2.0. Create and Populate the New Fact Tables
# #### 2.1. Extract Data from the Source MongoDB Collections Into DataFrames

# %%
query = {} # Select all elements (columns), and all documents (rows).

collection = "products"

df_products = get_mongo_dataframe(conn_str['local'], src_dbname, collection, query)
df_products.head(2)
# Out:
#                      Name   Brand Price DiscountedPrice Category  \
# 0  Premia Badam (Almonds)  Premia   451             329  Grocery
# 1  Premia Badam (Almonds)  Premia   109              85  Grocery
#
#           SubCategory Quantity Description                   BreadCrumbs
# 0  Grocery/Dry Fruits   500 gm       India  Grocery > Grocery/Dry Fruits
# 1  Grocery/Dry Fruits   100 gm       India  Grocery > Grocery/Dry Fruits

# %% [markdown]
# #### 2.2. Perform Any Necessary Transformations to the DataFrames

# %%
column_name_map = {"Name" : "name",
                   "Brand" : "brand",
                   "Price" : "price",
                   "DiscountedPrice" : "discounted_price",
                   "Category" : "category",
                   "SubCategory" : "sub_category",
                   "Quantity" : "quantity",
                  }

df_products.rename(columns=column_name_map, inplace=True)
df_products.insert(0, "product_key", range(1, df_products.shape[0]+1))

# %%
df_products = df_products.drop("Description", 1)
df_products = df_products.drop("BreadCrumbs", 1)
df_products
# Out:
# C:\Users\ds2002-02-student\AppData\Local\Temp\2\ipykernel_1820\2106963794.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_products = df_products.drop("Description", 1)
# C:\Users\ds2002-02-student\AppData\Local\Temp\2\ipykernel_1820\2106963794.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_products = df_products.drop("BreadCrumbs", 1)
#       product_key                                           name  \
# 0               1                         Premia Badam (Almonds)
# 1               2                         Premia Badam (Almonds)
# 2               3                         Premia Badam (Almonds)
# 3               4              Nutraj California Almonds (Badam)
# 4               5              Nutraj California Almonds (Badam)
# ...           ...                                            ...
# 3638         3639            Lotus Herbals Nutranite Night Creme
# 3639         3640         Lakme Absolute Hydra Pro Overnight Gel
# 3640         3641            Faces Canada Hydro Face Moisturizer
# 3641         3642    Lakme Absolute Perfect Radiance Facial Foam
# 3642         3643  Lakme Youth Infinity Skin Firming Night Cream
#
#              brand price discounted_price            category  \
# 0           Premia   451              329             Grocery
# 1           Premia   109               85             Grocery
# 2           Premia   202              175             Grocery
# 3           Nutraj   599              349             Grocery
# 4           Nutraj  1549              659             Grocery
# ...            ...   ...              ...                 ...
# 3638         Lotus   455              341  Beauty & Cosmetics
# 3639         Lakme   749              599  Beauty & Cosmetics
# 3640  Faces Canada   599              335  Beauty & Cosmetics
# 3641        Pond's   530              344  Beauty & Cosmetics
# 3642         Lakme   999              643  Beauty & Cosmetics
#
#                       sub_category quantity
# 0               Grocery/Dry Fruits   500 gm
# 1               Grocery/Dry Fruits   100 gm
# 2               Grocery/Dry Fruits   200 gm
# 3                       Dry Fruits   500 gm
# 4                       Dry Fruits     1 kg
# ...                            ...      ...
# 3638  Beauty & Cosmetics/Skin Care    50 gm
# 3639  Beauty & Cosmetics/Skin Care    50 gm
# 3640                     Face Care   100 ml
# 3641  Beauty & Cosmetics/Skin Care   130 ml
# 3642  Beauty & Cosmetics/Skin Care    50 gm
#
# [3643 rows x 8 columns]

# %% [markdown]
# #### 2.3. Load Newly Transformed MongoDB Data into the Northwind_DW2 Data Warehouse

# %%
dataframe = df_products
table_name = 'products'
primary_key = 'product_key'
db_operation = "insert"

set_dataframe(mysql_uid, mysql_pwd, dst_dbname, dataframe, table_name, primary_key, db_operation)

# %% [markdown]
# #### 2.4. Validate that the New Fact Tables were Created

# %%
# TODO: Validate the correctness of the new "Inventory Transactions" fact table.
sql_products = "SELECT * FROM supermart.products;"
df_products = get_sql_dataframe(mysql_uid, mysql_pwd, dst_dbname, sql_products)
df_products.head(2)
# Out:
#    product_key                    name   brand price discounted_price  \
# 0            1  Premia Badam (Almonds)  Premia   451              329
# 1            2  Premia Badam (Almonds)  Premia   109               85
#
#   category        sub_category quantity
# 0  Grocery  Grocery/Dry Fruits   500 gm
# 1  Grocery  Grocery/Dry Fruits   100 gm

# %% [markdown]
# #### 2.5. Date Dimension

# %%
sql_dim_date = "SELECT date_key, full_date FROM supermart.dim_date;"
df_dim_date = get_sql_dataframe(mysql_uid, mysql_pwd, dst_dbname, sql_dim_date)
df_dim_date.full_date = df_dim_date.full_date.astype('datetime64')
df_dim_date.head(2)
# Out:
#    date_key  full_date
# 0  20150101 2015-01-01
# 1  20150102 2015-01-02

# %%
df_customer["order_date"] = pd.to_datetime(df_customer["order_date"])
df_customer.dtypes
# Out:
# order_key                 int64
# customer_name            object
# category                 object
# sub_category             object
# city                     object
# order_date       datetime64[ns]
# region                   object
# sales                    object
# discount                 object
# profit                   object
# state                    object
# dtype: object

# %%
df_dim_order_date = df_dim_date.rename(columns={"date_key" : "order_date_key", "full_date" : "order_date"})
df_customer = pd.merge(df_customer, df_dim_order_date, on='order_date', how='inner')
df_customer.drop(['order_date'], axis=1, inplace=True)
df_customer.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 df_dim_order_date = df_dim_date.rename(columns={"date_key" : "order_date_key", "full_date" : "order_date"})
# ----> 2 df_customer = pd.merge(df_customer, df_dim_order_date, on='order_date', how='inner')
#       3 df_customer.drop(['order_date'], axis=1, inplace=True)
#       4 df_customer.head(50)
#
# File C:\Miniconda\envs\py38_default\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File C:\Miniconda\envs\py38_default\lib\site-packages\pandas\core\reshape\merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File C:\Miniconda\envs\py38_default\lib\site-packages\pandas\core\reshape\merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File C:\Miniconda\envs\py38_default\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'order_date'

# %%
df_customer.head(55)
# Out:
#     order_key customer_name           category        sub_category  \
# 0           1        Harish       Oil & Masala             Masalas
# 1           2         Sudha          Beverages       Health Drinks
# 2           3       Hussain        Food Grains        Atta & Flour
# 3          80         Veena   Fruits & Veggies      Organic Fruits
# 4          81         Kumar          Beverages       Health Drinks
# 5         120        Ganesh  Eggs, Meat & Fish             Chicken
# 6         121          Alan   Fruits & Veggies  Organic Vegetables
# 7         122        Harish             Bakery               Cakes
# 8         123      Veronica  Eggs, Meat & Fish              Mutton
# 9         124           Anu          Beverages         Soft Drinks
# 10        437           Ram  Eggs, Meat & Fish                Eggs
# 11        438         Aditi             Snacks             Noodles
# 12       3413       Rumaiza             Snacks             Noodles
# 13          4       Jackson   Fruits & Veggies    Fresh Vegetables
# 14          5       Ridhesh        Food Grains     Organic Staples
# 15          6        Adavan        Food Grains     Organic Staples
# 16          7         Jonas   Fruits & Veggies    Fresh Vegetables
# 17          8         Hafiz   Fruits & Veggies        Fresh Fruits
# 18          9         Hafiz             Bakery            Biscuits
# 19         10      Krithika             Bakery               Cakes
# 20         11        Ganesh             Snacks          Chocolates
# 21         12         Yadav  Eggs, Meat & Fish                Eggs
# 22        489       Haseena             Snacks             Cookies
# 23        490         Vidya             Snacks          Chocolates
# 24        491           Amy             Bakery               Cakes
# 25        861         Hafiz        Food Grains        Atta & Flour
# 26        862        Ramesh             Bakery       Breads & Buns
# 27       1335       Willams             Bakery               Cakes
# 28         13        Sharon             Snacks             Cookies
# 29        309        Esther             Snacks             Cookies
# 30         14          Peer   Fruits & Veggies    Fresh Vegetables
# 31        148        Harish   Fruits & Veggies    Fresh Vegetables
# 32        149      Veronica          Beverages       Health Drinks
# 33        150          Ravi  Eggs, Meat & Fish                Fish
# 34        151        Muneer        Food Grains                Rice
# 35       1083         Yadav        Food Grains        Atta & Flour
# 36       2758         Veena  Eggs, Meat & Fish              Mutton
# 37       2911        Sudeep       Oil & Masala              Spices
# 38         15        Sundar  Eggs, Meat & Fish             Chicken
# 39         16        Ramesh       Oil & Masala   Edible Oil & Ghee
# 40       2987         Malik             Snacks             Cookies
# 41       3024        Sharon             Snacks          Chocolates
# 42       3072         Komal  Eggs, Meat & Fish                Eggs
# 43         17          Alan             Bakery               Cakes
# 44        982           Ram        Food Grains       Dals & Pulses
# 45        983       Haseena       Oil & Masala   Edible Oil & Ghee
# 46        984           Ram          Beverages         Soft Drinks
# 47       1488        Suresh  Eggs, Meat & Fish                Fish
# 48       1526         Verma             Snacks             Noodles
# 49       1908         Vidya  Eggs, Meat & Fish              Mutton
# 50       3355       Hussain             Snacks             Cookies
# 51       3418         Veena          Beverages       Health Drinks
# 52       3443       Ridhesh             Snacks             Noodles
# 53       3460         Jonas        Food Grains       Dals & Pulses
# 54       3543        Arutra  Eggs, Meat & Fish              Mutton
#
#               city   region sales discount   profit       state  \
# 0          Vellore    North  1254     0.12   401.28  Tamil Nadu
# 1      Krishnagiri    South   749     0.18    149.8  Tamil Nadu
# 2       Perambalur     West  2360     0.21    165.2  Tamil Nadu
# 3          Chennai    South  2303     0.26   621.81  Tamil Nadu
# 4      Kanyakumari    South  2027     0.34   912.15  Tamil Nadu
# 5           Cumbum     East  1235     0.12     74.1  Tamil Nadu
# 6      Tirunelveli     East  1243     0.24   174.02  Tamil Nadu
# 7      Krishnagiri     East   649     0.34   201.19  Tamil Nadu
# 8          Tenkasi     East  2354     0.11   188.32  Tamil Nadu
# 9           Cumbum     East  1443     0.27   187.59  Tamil Nadu
# 10      Dharmapuri  Central  2200      0.1      792  Tamil Nadu
# 11         Tenkasi  Central   861     0.25    258.3  Tamil Nadu
# 12          Trichy  Central  2023     0.34   627.13  Tamil Nadu
# 13      Dharmapuri    South   896     0.25     89.6  Tamil Nadu
# 14            Ooty    South  2355     0.26   918.45  Tamil Nadu
# 15      Dharmapuri     West  2305     0.26    322.7  Tamil Nadu
# 16          Trichy     West   826     0.33   346.92  Tamil Nadu
# 17  Ramanadhapuram     West  1847     0.32   147.76  Tamil Nadu
# 18     Tirunelveli     West   791     0.23   181.93  Tamil Nadu
# 19         Chennai     West  1795     0.27   484.65  Tamil Nadu
# 20           Karur     West  1903     0.13   437.69  Tamil Nadu
# 21        Namakkal     West   701      0.1   308.44  Tamil Nadu
# 22  Ramanadhapuram  Central  1637      0.3   572.95  Tamil Nadu
# 23  Ramanadhapuram  Central  2232      0.1   870.48  Tamil Nadu
# 24     Tirunelveli  Central  1917     0.22   843.48  Tamil Nadu
# 25      Viluppuram     West  1426     0.18    570.4  Tamil Nadu
# 26           Karur     West  1263     0.13    88.41  Tamil Nadu
# 27           Karur    South   697     0.22   132.43  Tamil Nadu
# 28        Dindigul    South  1659     0.19   315.21  Tamil Nadu
# 29         Tenkasi    South   590     0.27    200.6  Tamil Nadu
# 30     Kanyakumari     West  1277     0.25    63.85  Tamil Nadu
# 31     Tirunelveli  Central  1125     0.33    292.5  Tamil Nadu
# 32         Tenkasi  Central   768      0.1   184.32  Tamil Nadu
# 33         Vellore  Central  1985     0.26   734.45  Tamil Nadu
# 34            Bodi  Central  2287     0.13  1029.15  Tamil Nadu
# 35         Tenkasi    South   859     0.34   180.39  Tamil Nadu
# 36           Karur     East  1992     0.28   418.32  Tamil Nadu
# 37      Viluppuram    South  2100     0.14      315  Tamil Nadu
# 38     Kanyakumari  Central   831     0.22   207.75  Tamil Nadu
# 39     Krishnagiri  Central  1440     0.11    100.8  Tamil Nadu
# 40         Madurai     West  1449     0.15   623.07  Tamil Nadu
# 41  Ramanadhapuram     West  1174     0.16    117.4  Tamil Nadu
# 42            Ooty     West  1869      0.1   485.94  Tamil Nadu
# 43      Dharmapuri  Central  1678     0.28   318.82  Tamil Nadu
# 44      Dharmapuri     West   911     0.24     91.1  Tamil Nadu
# 45        Dindigul     West  1722     0.21   154.98  Tamil Nadu
# 46         Chennai     West  1660     0.33    315.4  Tamil Nadu
# 47           Salem  Central  1493     0.16   477.76  Tamil Nadu
# 48        Dindigul  Central  1612     0.18   435.24  Tamil Nadu
# 49  Ramanadhapuram     West  2213     0.22   840.94  Tamil Nadu
# 50        Namakkal  Central   722     0.33   317.68  Tamil Nadu
# 51            Ooty  Central  1676     0.32   150.84  Tamil Nadu
# 52       Nagercoil  Central  2099     0.12   860.59  Tamil Nadu
# 53           Theni  Central   739     0.12    88.68  Tamil Nadu
# 54          Cumbum  Central  2068     0.24   558.36  Tamil Nadu
#
#     order_date_key
# 0         20171108
# 1         20171108
# 2         20170612
# 3         20170612
# 4         20170612
# 5         20170612
# 6         20170612
# 7         20170612
# 8         20170612
# 9         20170612
# 10        20170612
# 11        20170612
# 12        20170612
# 13        20161011
# 14        20161011
# 15        20150609
# 16        20150609
# 17        20150609
# 18        20150609
# 19        20150609
# 20        20150609
# 21        20150609
# 22        20150609
# 23        20150609
# 24        20150609
# 25        20150609
# 26        20150609
# 27        20150609
# 28        20180415
# 29        20180415
# 30        20171205
# 31        20171205
# 32        20171205
# 33        20171205
# 34        20171205
# 35        20171205
# 36        20171205
# 37        20171205
# 38        20161122
# 39        20161122
# 40        20161122
# 41        20161122
# 42        20161122
# 43        20151111
# 44        20151111
# 45        20151111
# 46        20151111
# 47        20151111
# 48        20151111
# 49        20151111
# 50        20151111
# 51        20151111
# 52        20151111
# 53        20151111
# 54        20151111
